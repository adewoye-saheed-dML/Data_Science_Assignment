# %%
import numpy as np
import pandas as pd

# %%
# Read the dataset from your local path on your computer
data = pd.read_csv('C:/Users/WOYES/Downloads/timeseries/train.csv', delimiter = ',')

# Display the first five rows of the datas
data.head()
# Out:
#          Date  store  product  number_sold
# 0  2010-01-01      0        0          801
# 1  2010-01-02      0        0          810
# 2  2010-01-03      0        0          818
# 3  2010-01-04      0        0          796
# 4  2010-01-05      0        0          808

# %%
# check the datatype of each column in the dataset
data.dtypes
# Out:
# Date           object
# store           int64
# product         int64
# number_sold     int64
# dtype: object

# %%
# Convert the 'Date' column to a datetime data type

data['Date'] = pd.to_datetime(data['Date'], format= '%Y-%m-%d')

# Recheck the data type
data.dtypes
# Out:
# Date           datetime64[ns]
# store                   int64
# product                 int64
# number_sold             int64
# dtype: object

# %%
# Set 'Date' as the index of a DataFrame
data.set_index(['Date'], inplace=True)
data.head()
# Out:
#             store  product  number_sold
# Date
# 2010-01-01      0        0          801
# 2010-01-02      0        0          810
# 2010-01-03      0        0          818
# 2010-01-04      0        0          796
# 2010-01-05      0        0          808

# %%
# Resample data to monthly frequency (the resampling is done at the beginning of each month)
data_resampled = data.resample('MS').sum()

# Filtering the result to include only the first day rows of each month.
data_resampled_1st_day = data_resampled[data_resampled.index.day == 1]
data_resampled_1st_day
# Out:
#             store  product  number_sold
# Date
# 2010-01-01   6510     9765      1698403
# 2010-02-01   5880     8820      1529750
# 2010-03-01   6510     9765      1688388
# 2010-04-01   6300     9450      1630998
# 2010-05-01   6510     9765      1685240
# ...           ...      ...          ...
# 2018-08-01   6510     9765      1709901
# 2018-09-01   6300     9450      1660685
# 2018-10-01   6510     9765      1717400
# 2018-11-01   6300     9450      1663840
# 2018-12-01   6510     9765      1716870
#
# [108 rows x 3 columns]

# %%
# Select data for a specific date range
data_slice = data['2010-01-01':'2018-12-31']
print(data_slice)

# Using .loc for Slicing
data_slice = data.loc['2010-01-01':'2018-12-31']
print(data_slice)
# Out:
#             store  product  number_sold
# Date
# 2010-01-01      0        0          801
# 2010-01-02      0        0          810
# 2010-01-03      0        0          818
# 2010-01-04      0        0          796
# 2010-01-05      0        0          808
# ...           ...      ...          ...
# 2018-12-27      6        9          890
# 2018-12-28      6        9          892
# 2018-12-29      6        9          895
# 2018-12-30      6        9          899
# 2018-12-31      6        9          912
#
# [230090 rows x 3 columns]
#             store  product  number_sold
# Date
# 2010-01-01      0        0          801
# 2010-01-02      0        0          810
# 2010-01-03      0        0          818
# 2010-01-04      0        0          796
# 2010-01-05      0        0          808
# ...           ...      ...          ...
# 2018-12-27      6        9          890
# 2018-12-28      6        9          892
# 2018-12-29      6        9          895
# ...

# %%
# Create a new column with future number of sold
data['future_sold'] = data['number_sold'].shift(-1)

# print the last 5 rows
data.tail()
# Out:
#             store  product  number_sold  future_sold
# Date
# 2018-12-27      6        9          890        892.0
# 2018-12-28      6        9          892        895.0
# 2018-12-29      6        9          895        899.0
# 2018-12-30      6        9          899        912.0
# 2018-12-31      6        9          912          NaN

# %%
# Calculate the difference between current and future number_sold
data['sold_difference'] = data['future_sold'] - data['number_sold']
data.tail()
# Out:
#             store  product  number_sold  future_sold  sold_difference
# Date
# 2018-12-27      6        9          890        892.0              2.0
# 2018-12-28      6        9          892        895.0              3.0
# 2018-12-29      6        9          895        899.0              4.0
# 2018-12-30      6        9          899        912.0             13.0
# 2018-12-31      6        9          912          NaN              NaN

# %%
# Calculate rolling mean over a window of size 3
data['rolling_mean'] = data['number_sold'].rolling(window=3).mean() #You decide on a window size, here 3days
data.head()
# Out:
#             store  product  number_sold  future_sold  rolling_mean
# Date
# 2010-01-01      0        0          801        810.0           NaN
# 2010-01-02      0        0          810        818.0           NaN
# 2010-01-03      0        0          818        796.0    809.666667
# 2010-01-04      0        0          796        808.0    808.000000
# 2010-01-05      0        0          808        812.0    807.333333

# %%
# Compute differences
data['differencing'] = data['number_sold'].diff()
data.head()
# Out:
#          Date  store  product  number_sold  differencing
# 0  2010-01-01      0        0          801           NaN
# 1  2010-01-02      0        0          810           9.0
# 2  2010-01-03      0        0          818           8.0
# 3  2010-01-04      0        0          796         -22.0
# 4  2010-01-05      0        0          808          12.0

# %%
# checking for missing values
data.isnull()
# Out:
#          Date  store  product  number_sold  differencing
# 0       False  False    False        False          True
# 1       False  False    False        False         False
# 2       False  False    False        False         False
# 3       False  False    False        False         False
# 4       False  False    False        False         False
# ...       ...    ...      ...          ...           ...
# 230085  False  False    False        False         False
# 230086  False  False    False        False         False
# 230087  False  False    False        False         False
# 230088  False  False    False        False         False
# 230089  False  False    False        False         False
#
# [230090 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot time series data
data['number_sold'].plot()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
